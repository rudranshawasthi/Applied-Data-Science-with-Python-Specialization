# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# df = pd.read_csv('total_cases.csv')
# l = df.columns.tolist()[:2]
# w = df[l]
# w = w.set_index('date')

# %%
# c = df[['India','United States','Italy','Russia','United Kingdom']]
# # fig, ax = plt.subplots()
# d = df['date']
# d = d.iloc[-90:]
# c = c.iloc[-90:]
# _=plt.plot(d,c['India'],label='India')

# _=plt.plot(d,c['United States'],label='United States')
# _=plt.plot(d,c['Italy'],label='Italy')
# _=plt.plot(d,c['Russia'],label='Russia')
# _=plt.plot(d,c['United Kingdom'],label='United Kingdom')
# _=plt.xticks(d.iloc[::20])
# plt.legend()

# %%
df1 = pd.read_csv('covid_19_india.csv')
df1 = df1.drop(['ConfirmedIndianNational', 'ConfirmedForeignNational','Time','Sno'], axis = 1)
df1 = df1.set_index(['Date','State/UnionTerritory'])
# df1 = df1.set_index(['location','date'])
# df1.loc['India']

# %%
df1 = df1.drop('Cases being reassigned to states',level = 'State/UnionTerritory')
df1['Active'] = df1['Confirmed']-(df1['Cured']+df1['Deaths'])

# %%
#df1 = df1.drop(['Cured','Deaths'],axis =1)
df1 = df1.reset_index()

# %%
State = df1[df1['State/UnionTerritory']=='Kerala']
State = State.drop('State/UnionTerritory',axis=1)
date = State['Date']
mi = State[70:].groupby('Active').agg(min).iloc[0]['Date']
State = State.drop('Date',axis = 1)
# mi = mi['Date']
mi
# Out:
# '09/05/20'

# %%
# %matplotlib notebook
plt.figure()
plt.style.use('seaborn')
_ = plt.plot(date,State['Confirmed'],label = 'Confirmed',alpha = 0.5)
_ = plt.bar(date,State['Active'], label = 'Active',alpha=.5)
_ = plt.plot(date,State['Cured'],label='Cured',alpha= .8)
_ = plt.xticks(date[::20])
# plt.axvline(x=mi,color = 'grey')
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(axis='both', which='both', length=0)
plt.legend(frameon=False)
plt.title('COVID19 status in Kerala')
plt.xlabel('Dates')
plt.ylabel('People')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, 'People')

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']
